# %% [markdown]
# <a href="https://colab.research.google.com/github/Eswar1917/FMML_Project_and_Labs/blob/main/Module8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-23 03:21:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   130MB/s    in 0.5s
#
# 2025-04-23 03:22:00 (130 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6189   1609.02606v2  We consider the best-arm identification proble...  stat
# 3841   1607.05108v1  Knowing which words have been attended to in p...    cs
# 22724  1705.07168v1  Data-driven Distributionally Robust Optimizati...  stat
# 21833   1302.5134v1  Spectral clustering (SC) and graph-based semi-...  stat
# 10575   1309.0337v1  We present an LDA approach to entity disambigu...  stat
# ...             ...                                                ...   ...
# 18709   1110.2735v1  The best performing algorithms for a particula...    cs
# 6967   1708.04106v3  Models applied on real time response task, lik...  stat
# 35995   0903.1139v1  Constraint propagation is one of the technique...    cs
# 20836  1703.06321v2  Influence diagrams are a decision-theoretic ex...    cs
# 29408  1709.03138v1  One of the most important parts of environment...    cs
#
#                                                    title  year  \
# 6189   On Sequential Elimination Algorithms for Best-...  2016
# 3841   Neural Machine Translation with Recurrent Atte...  2016
# 22724  Doubly Robust Data-Driven Distributionally Rob...  2017
# 21833           Spectral Clustering with Unbalanced Data  2013
# 10575       Scalable Probabilistic Entity-Topic Modeling  2013
# ...                                                  ...   ...
# 18709  Understanding Algorithm Performance on an Over...  2011
# 6967   Rocket Launching: A Universal and Efficient Fr...  2017
# 35995  The Complexity of Reasoning with Global Constr...  2009
# 20836  Solving the Goddard problem by an influence di...  2017
# 29408  Fully Convolutional Neural Networks for Dynami...  2017
#
#                                                 keywords
# 6189   [identification, exploration, independently, d...
# 3841   [generating, translation, information, predict...
# 22724  [distributionally, optimization, transport, en...
# 21833  [clustering, supervised, algorithms, sensitive...
# 10575  [disambiguation, associated, wikipedia, challe...
# ...                                                  ...
# 18709  [performing, algorithms, particular, oversubsc...
# 6967   [prediction, therefore, performing, complexity...
# 35995  [constraint, propagation, techniques, constrai...
# 20836  [influence, theoretic, extension, probabilisti...
# 29408  [important, environment, perception, detection...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6189     [identification, exploration, independently, d...
# 3841     [generating, translation, information, predict...
# 22724    [distributionally, optimization, transport, en...
# 21833    [clustering, supervised, algorithms, sensitive...
# 10575    [disambiguation, associated, wikipedia, challe...
#                                ...
# 2346     [probabilistic, variables, variables, variable...
# 11918    [generalize, classification, recognition, regu...
# 6703     [statistical, divergences, textitrelaxed, wass...
# 9326     [supervised, selection, responsible, predictin...
# 22856    [framework, hamiltonian, truncated, probabilit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8844 words.
# Out of those 4582 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="97ff8c65-46b5-4c2a-ac28-b204cd5c0032" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97ff8c65-46b5-4c2a-ac28-b204cd5c0032")) {                    Plotly.newPlot(                        "97ff8c65-46b5-4c2a-ac28-b204cd5c0032",                        [{"x":["nonlinear","algorithms","competitive","framework","mechanism","eliminated","described","experiments","expressed","establish","guarantees","distribution","according","theoretical","exploration","identification","outperforms","observation","nonlinearity","algorithm","environments","independently","sequential","different","performance","iteratively","characterizing","remaining","elimination","informative","translation","generating","architecture","subsequent","attention","predicting","information","regularities","relationship","recurrent","parameterization","explicitly","distortion","empirically","estimators","classifiers","uncertainty","properties","definition","optimization","transportation","underlying","robustification","corresponds","regularization","generalization","encompass","regularized","transport","methodology","distributionally","distributional","correspond","parameter","additional","clustering","particular","adaptively","superiority","selection","modulating","unsupervised","unbalancedness","unbalanced","objectives","partitioning","theoretically","normalized","sensitive","constructed","separated","synthetic","supervised","detection","naturally","demonstrate","parameterizes","vocabulary","wikipedia","inference","pipelines","challenging","associated","processing","disambiguation","probabilistic","representation","distributed","mapreduce","techniques","significant","benchmark","biomedical","automatically","substantial","indicating","knowledge","predicted","furthermore","essential","conjunction","regresses","projections","detectors","predictors","successful","locations","practices","employing","compressed","dimension","microscopy","convolutional","attributed","extensively","heuristic","connected","convergence","concurrent","literature","detecting","constraints","specialize","functions","coherence","scenarios","univariate","application","empirical","interesting","customized","attributes","including","demonstrates","structured","subgraphs","specifically","analogous","applications","anomalous","preliminary","structure","accessible","promising","community","determinantal","processes","efficient","measurements","investigate","especially","permutation","algebraic","manipulation","artificial","exploiting","solutions","symmetries","computational","structural","understanding","posteriors","isotropic","consequences","variational","truncated","generalize","distributions","objective","quantitative","approximation","following","likelihood","generalizations","gaussians","equivalent","assumption","smoothness","sparseness","asymptotics","embedding","laplacians","laplacian","appropriate","constructions","construction","approaches","shrinking","previously","introduce"],"y":[65,581,101,542,113,3,81,614,40,60,60,222,116,152,57,99,280,69,7,860,82,32,60,765,899,43,12,21,6,33,115,109,244,25,183,71,655,6,73,136,8,68,20,65,9,112,83,198,49,306,16,121,0,26,88,100,3,37,14,74,1,20,19,113,127,146,287,28,41,144,1,145,0,8,34,12,47,22,66,64,11,145,172,351,68,539,2,26,22,220,8,252,98,292,17,156,371,92,9,375,224,237,18,184,44,12,340,56,166,61,22,2,29,32,7,61,44,12,35,25,63,7,381,8,29,60,96,100,3,127,69,142,2,202,18,85,4,240,159,66,7,52,267,59,93,6,182,15,437,2,52,333,11,117,71,2,80,369,53,159,143,10,12,20,114,74,161,7,290,57,144,3,3,7,59,8,54,93,171,75,107,93,70,7,7,50,72,14,5,1,100,0,10,73,7,60,447,3,100,359],"type":"bar"},{"x":["nonlinear","algorithms","competitive","framework","mechanism","eli ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4582,), (4582, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.825

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Why</span> <span style=''>PairDiff</span> <span style=''>works</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mathematical</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Bilinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relational</span> <span style='background-color:rgba(0, 255, 0, 0.6799999999999999);'>Compositional</span> <span style='background-color:rgba(0, 255, 0, 0.408450704225352);'>Operators</span> <span style=''>for</span> <span style=''>Analogy</span> <span style='background-color:rgba(0, 255, 0, 0.5462555066079295);'>Detection</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4038461538461539);'>Representing</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.47008547008547014);'>relations</span> <span style=''>that</span> <span style=''>exist</span> <span style=''>between</span> <span style=''>two</span> <span style=''>given</span> <span style=''>words</span> <span style=''>(or</span> <span style=''>entities)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>first</span> <span style=''>step</span> <span style=''>in</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>NLP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>analogical</span> <span style='background-color:rgba(0, 255, 0, 0.7972972972972974);'>reasoning</span> <span style='background-color:rgba(0, 255, 0, 0.3600000000000001);'>knowledge</span> <span style=''>base</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.5797101449275361);'>retrieval</span> <span style=''>A</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprisingly</span> <span style=''>accurate</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4038461538461539);'>representing</span> <span style=''>a</span> <span style=''>relation</span> <span style=''>between</span> <span style=''>two</span> <span style=''>words</span> <span style=''>is</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>vector</span> <span style=''>offset</span> <span style=''>(PairDiff)</span> <span style=''>between</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>Despite</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>success</span> <span style=''>it</span> <span style=''>remains</span> <span style=''>unclear</span> <span style=''>as</span> <span style=''>to</span> <span style=''>whether</span> <span style=''>PairDiff</span> <span style=''>is</span> <span style=''>the</span> <span style=''>best</span> <span style=''>operator</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relational</span> <span style='background-color:rgba(0, 255, 0, 0.37153419593345655);'>representation</span> <span style=''>from</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>We</span> <span style=''>conduct</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifiability</span> <span style=''>of</span> <span style=''>Mixture</span> <span style=''>Models</span> <span style=''>from</span> <span style=''>Grouped</span> <span style=''>Samples</span> <br/><br/><span style=''>Finite</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>which</span> <span style=''>appear</span> <span style=''>in</span> <span style=''>many</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>such</span> <span style=''>models</span> <span style=''>it</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>that</span> <span style=''>data</span> <span style=''>are</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>called</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>themselves</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measure</span> <span style=''>P</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>it</span> <span style=''>is</span> <span style=''>common</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>make</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>on</span> <span style=''>the</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>and</span> <span style=''>instead</span> <span style=''>assume</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>from</span> <span style=''>the</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>are</span> <span style=''>grouped</span> <span style=''>such</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style=''>group</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>any</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>m</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Hinge</span> <span style=''>loss</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Fields</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.44047619047619047);'>Graphical</span> <span style=''>models</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>domains</span> <span style=''>are</span> <span style=''>powerful</span> <span style=''>tools</span> <span style=''>but</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>spaces</span> <span style=''>can</span> <span style=''>force</span> <span style='background-color:rgba(0, 255, 0, 0.47058823529411753);'>restrictions</span> <span style=''>on</span> <span style=''>models</span> <span style=''>or</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>working</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style=''>space</span> <span style=''>we</span> <span style=''>use</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>(HL</span> <span style=''>MRFs)</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.44047619047619047);'>graphical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>log</span> <span style=''>concave</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.43576826196473545);'>variables</span> <span style=''>which</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3260869565217392);'>represent</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>confidences</span> <span style=''>in</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrates</span> <span style=''>that</span> <span style=''>HL</span> <span style=''>MRFs</span> <span style=''>are</span> <span style=''>general</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style=''>based</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>to</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>tasks</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accomplished</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>error</span> <span style=''>rate</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>data</span> <span style=''>subject</span> <span style=''>to</span> <span style=''>ground</span> <span style=''>truth</span> <span style=''>labeling</span> <span style=''>by</span> <span style=''>human</span> <span style=''>experts</span> <span style=''>or</span> <span style=''>some</span> <span style=''>other</span> <span style=''>means</span> <span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>systems</span> <span style=''>and</span> <span style=''>other</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>however</span> <span style=''>such</span> <span style=''>labeled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>costly</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>This</span> <span style=''>article</span> <span style=''>proposes</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>by</span> <span style=''>using</span> <span style=''>trained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>each</span> <span style=''>model</span> <span style=''>to</span> <span style='background-color:rgba(255 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12173290368779091)
# 	experimental (0.1260293591120659)
# 	processing (0.10454708199069102)
# 	representation (0.13283208020050125)
# 	segmentation (0.06910132474042248)
# 	architecture (0.08736126029359112)
# 	detection (0.12567132116004295)
# 	different (0.2738990332975295)
# 	recognition (0.13211600429645542)
# 	convolutional (0.1364124597207304)
#
# Some Statistics words are:
# 	algorithm (0.388141504733433)
# 	stochastic (0.13153961136023917)
# 	estimation (0.17189835575485798)
# 	statistical (0.15445939212755355)
# 	theoretical (0.15445939212755355)
# 	variables (0.14200298953662183)
# 	distribution (0.18236173393124067)
# 	inference (0.2012954658694569)
# 	dimensional (0.19133034379671152)
# 	regression (0.17638266068759342)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="daff4c7d-163a-4da5-b205-4ec032168a8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daff4c7d-163a-4da5-b205-4ec032168a8f")) {                    Plotly.newPlot(                        "daff4c7d-163a-4da5-b205-4ec032168a8f",                        [{"x":["nonlinear","algorithms","competitive","framework","mechanism","eliminated","described","experiments","expressed","establish","guarantees","distribution","according","theoretical","exploration","identification","outperforms","observation","nonlinearity","algorithm","environments","independently","sequential","different","performance","iteratively","characterizing","remaining","elimination","informative","translation","generating","architecture","subsequent","attention","predicting","information","regularities","relationship","recurrent","parameterization","explicitly","distortion","empirically","estimators","classifiers","uncertainty","properties","definition","optimization","transportation","underlying","robustification","corresponds","regularization","generalization","encompass","regularized","transport","methodology","distributionally","distributional","correspond","parameter","additional","clustering","particular","adaptively","superiority","selection","modulating","unsupervised","unbalancedness","unbalanced","objectives","partitioning","theoretically","normalized","sensitive","constructed","separated","synthetic","supervised","detection","naturally","demonstrate","parameterizes","vocabulary","wikipedia","inference","pipelines","challenging","associated","processing","disambiguation","probabilistic","representation","distributed","mapreduce","techniques","significant","benchmark","biomedical","automatically","substantial","indicating","knowledge","predicted","furthermore","essential","conjunction","regresses","projections","detectors","predictors","successful","locations","practices","employing","compressed","dimension","microscopy","convolutional","attributed","extensively","heuristic","connected","convergence","concurrent","literature","detecting","constraints","specialize","functions","coherence","scenarios","univariate","application","empirical","interesting","customized","attributes","including","demonstrates","structured","subgraphs","specifically","analogous","applications","anomalous","preliminary","structure","accessible","promising","community","determinantal","processes","efficient","measurements","investigate","especially","permutation","algebraic","manipulation","artificial","exploiting","solutions","symmetries","computational","structural","understanding","posteriors","isotropic","consequences","variational","truncated","generalize","distributions","objective","quantitative","approximation","following","likelihood","generalizations","gaussians","equivalent","assumption","smoothness","sparseness","asymptotics","embedding","laplacians","laplacian","appropriate","constructions","construction","approaches","shrinking","previously","introduce","assumptions","convergent","neighborhoods","typically","desirable","analyzing","investigates","classifier","precision","dimensions","proliferation","opinionated","discussion","representative","documents","investigated","adversely","attitudes","applicability","discrimination","consistent","extracting","frequency","investigation","experimental","classification","sentiment","morphological","complementary","computation","components","introduction","sufficient","mechanisms","evolutionary","available","combination","coevolution","restriction","approximately","describes","morphology","intermediate","creatures","behavioral","preservation","constrains","evolution","increasing","presented","resources","complexity","extensions ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	robustification
# 	unbalancedness
# 	laplacians
# 	variabilities
# 	spectroscopy
# 	hemoglobin
# 	subexponential
# 	hermitian
# 	distilled
# 	ancillary
# 	invariably
# 	reseeding
# 	straggler
# 	equiangular
# 	stragglers
# 	reassignment
# 	independencies
# 	determinants
# 	reparameterizations
# 	counterexample
# Some words which never appear in Statistics papers:
# 	concurrent
# 	manipulation
# 	opinionated
# 	coevolution
# 	creatures
# 	compositionality
# 	accommodated
# 	imitating
# 	superresolution
# 	satisfiability
# 	delineated
# 	referring
# 	recognizers
# 	radiometrically
# 	radiometric
# 	parametrised
# 	activitynet
# 	untrimmed
# 	stagnation
# 	originality

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075787401574804e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7908333333333334
